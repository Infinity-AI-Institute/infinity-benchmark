# %%
from omega_models import AdaptiveAbstractionForest
from data_loader import load, test_on_infinity_benchmark, test_on_all_datasets, test_on_datasets

# %%
# Run the model on the entire Infinity Benchmark
model = AdaptiveAbstractionForest()
scores = test_on_infinity_benchmark(model)
# Out:
# Loaded builtin dataset: Iris
# Loaded builtin dataset: Wine
# Loaded builtin dataset: Breast Cancer
# Loaded builtin dataset: Digits
# Loaded OpenML dataset: Balance Scale (cap=None)
# Loaded OpenML dataset: Blood Transfusion (cap=None)
# Loaded OpenML dataset: Haberman (cap=None)
# Loaded OpenML dataset: Seeds (cap=None)
# Loaded OpenML dataset: Teaching Assistant (cap=None)
# Loaded OpenML dataset: Zoo (cap=None)
# Loaded OpenML dataset: Planning Relax (cap=None)
# Loaded OpenML dataset: Ionosphere (cap=None)
# Loaded OpenML dataset: Sonar (cap=None)
# Loaded OpenML dataset: Glass (cap=None)
# Loaded OpenML dataset: Vehicle (cap=None)
# Loaded OpenML dataset: Liver Disorders (cap=None)
# Loaded OpenML dataset: Heart Statlog (cap=None)
# Loaded OpenML dataset: Pima Indians Diabetes (cap=None)
# Loaded OpenML dataset: Australian (cap=None)
# Loaded OpenML dataset: Monks-1 (cap=None)
# Iris                      acc=0.9667  time=0.04s
# Wine                      acc=1.0000  time=0.06s
# ...

# %%
scores = test_on_all_datasets(model)
# Out:
# Loaded builtin dataset: Iris
# Loaded builtin dataset: Wine
# Loaded builtin dataset: Breast Cancer
# Loaded builtin dataset: Digits
# Loaded OpenML dataset: Balance Scale (cap=None)
# Loaded OpenML dataset: Blood Transfusion (cap=None)
# Loaded OpenML dataset: Haberman (cap=None)
# Loaded OpenML dataset: Seeds (cap=None)
# Loaded OpenML dataset: Teaching Assistant (cap=None)
# Loaded OpenML dataset: Zoo (cap=None)
# Loaded OpenML dataset: Planning Relax (cap=None)
# Loaded OpenML dataset: Ionosphere (cap=None)
# Loaded OpenML dataset: Sonar (cap=None)
# Loaded OpenML dataset: Glass (cap=None)
# Loaded OpenML dataset: Vehicle (cap=None)
# Loaded OpenML dataset: Liver Disorders (cap=None)
# Loaded OpenML dataset: Heart Statlog (cap=None)
# Loaded OpenML dataset: Pima Indians Diabetes (cap=None)
# Loaded OpenML dataset: Australian (cap=None)
# Loaded OpenML dataset: Monks-1 (cap=None)
# Loaded OpenML dataset: Adult Census Income (cap=50000)
# Loaded OpenML dataset: Credit-g (cap=None)
# ...

# %%
# Score your model on specific datasets
scores = test_on_datasets(model, ["Iris", "Wine", "Monks-1"])
# Out:
# Loaded builtin dataset: Iris
# Loaded builtin dataset: Wine
# Loaded OpenML dataset: Monks-1 (cap=None)
# Iris                      acc=0.9667  time=0.04s
# Wine                      acc=1.0000  time=0.06s
# Monks-1                   acc=0.9196  time=0.05s

# %%
# Load specific datasets to have access to their details
datasets = load(["Iris", "Wine", "Breast Cancer"])
X_train, X_test, y_train, y_test = datasets["Iris"]
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 120 30 120 30

# %%
# Change loading details to your preference (see API reference for more options)
datasets = load(["Iris", "Wine", "Breast Cancer"], test_size=0.1)
X_train, X_test, y_train, y_test = datasets["Iris"]
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 135 15 135 15
